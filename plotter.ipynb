-23-17-6 14-28-23-17-6 16-28-23-17-6 17-28-23-17-6 18-28-23-17-6 19-28-23-17-6 20-28-23-17-6 21-28-23-17-6 22-28-23-17-6 23-28-23-17-6 24-28-23-17-6 25-28-23-17-6 26-28-23-17-6 27-28-23-17-6 29-28-23-17-6 30-28-23-17-6 31-28-23-17-6 0-9-23-17-6 1-9-23-17-6 2-9-23-17-6 3-9-23-17-6 4-9-23-17-6 5-9-23-17-6 6-9-23-17-6 7-9-23-17-6 8-9-23-17-6 9-9-23-17-6 10-9-23-17-6 11-9-23-17-6 12-9-23-17-6 13-9-23-17-6 14-9-23-17-6 15-9-23-17-6 16-9-23-17-6 17-9-23-17-6 18-9-23-17-6 19-9-23-17-6 20-9-23-17-6 21-9-23-17-6 22-9-23-17-6 23-9-23-17-6 24-9-23-17-6 25-9-23-17-6 26-9-23-17-6 27-9-23-17-6 28-9-23-17-6 29-9-23-17-6 30-9-23-17-6 31-9-23-17-6 0-9-23-17-6 1-9-23-17-6 2-9-23-17-6 3-9-23-17-6 4-9-23-17-6 5-9-23-17-6 6-9-23-17-6 7-9-23-17-6 8-9-23-17-6 9-9-23-17-6 10-9-23-17-6 11-9-23-17-6 12-9-23-17-6 13-9-23-17-6 14-9-23-17-6 15-9-23-17-6 16-9-23-17-6 17-9-23-17-6 18-9-23-17-6 19-9-23-17-6 20-9-23-17-6 21-9-23-17-6 22-9-23-17-6 23-9-23-17-6 24-9-23-17-6 25-9-23-17-6 26-9-23-17-6 27-9-23-17-6 28-9-23-17-6 29-9-23-17-6 30-9-23-17-6 31-9-23-17-6
"""

# %%
from PIL import Image, ImageDraw

# Function to parse the input string and generate a list of (x, y, (r, g, b))
def parse_input(data_str):
    points = []
    data_list = data_str.split()
    for item in data_list:
        x, y, r, g, b = map(int, item.split('-'))
        points.append((x, y, (r, g, b)))
    return points

# Function to draw the matrix based on the parsed points with a black border
def draw_matrix(points, width, height):
    # Create a new blank image with white background
    img = Image.new('RGB', (width, height), 'black')
    draw = ImageDraw.Draw(img)

    # Define the size of each cell in the grid
    cell_size = 10

    # Draw each point with a black border
    for x, y, color in points:
        top_left = (x * cell_size, y * cell_size)
        bottom_right = ((x + 1) * cell_size, (y + 1) * cell_size)
        draw.rectangle([top_left, bottom_right], fill=color, outline='black')

    # Show the image
    img.show()

points = parse_input(data_str)
draw_matrix(points, width=320, height=320)
