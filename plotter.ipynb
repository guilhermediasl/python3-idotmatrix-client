23-17-6 12-9-23-17-6 13-9-23-17-6 14-9-23-17-6 15-9-23-17-6 16-9-23-17-6 17-9-23-17-6 18-9-23-17-6 19-9-23-17-6 20-9-23-17-6 21-9-23-17-6 22-9-23-17-6 23-9-23-17-6 24-9-23-17-6 25-9-23-17-6 26-9-23-17-6 27-9-23-17-6 28-9-23-17-6 29-9-23-17-6 30-9-23-17-6 31-9-23-17-6 0-9-23-17-6 1-9-23-17-6 2-9-23-17-6 3-9-23-17-6 4-9-23-17-6 5-9-23-17-6 6-9-23-17-6 7-9-23-17-6 8-9-23-17-6 9-9-23-17-6 10-9-23-17-6 11-9-23-17-6 12-9-23-17-6 13-9-23-17-6 14-9-23-17-6 15-9-23-17-6 16-9-23-17-6 17-9-23-17-6 18-9-23-17-6 19-9-23-17-6 20-9-23-17-6 21-9-23-17-6 22-9-23-17-6 23-9-23-17-6 24-9-23-17-6 25-9-23-17-6 26-9-23-17-6 27-9-23-17-6 28-9-23-17-6 29-9-23-17-6 30-9-23-17-6 31-9-23-17-6
"""

# %%
from PIL import Image, ImageDraw

# Function to parse the input string and generate a list of (x, y, (r, g, b))
def parse_input(data_str):
    points = []
    data_list = data_str.split()
    for item in data_list:
        x, y, r, g, b = map(int, item.split('-'))
        points.append((x, y, (r, g, b)))
    return points

# Function to draw the matrix based on the parsed points with a black border
def draw_matrix(points, width, height):
    # Create a new blank image with white background
    img = Image.new('RGB', (width, height), 'black')
    draw = ImageDraw.Draw(img)

    # Define the size of each cell in the grid
    cell_size = 10

    # Draw each point with a black border
    for x, y, color in points:
        top_left = (x * cell_size, y * cell_size)
        bottom_right = ((x + 1) * cell_size, (y + 1) * cell_size)
        draw.rectangle([top_left, bottom_right], fill=color, outline='black')

    # Show the image
    img.show()

points = parse_input(data_str)
draw_matrix(points, width=320, height=320)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 30
#      27     # Show the image
#      28     img.show()
# ---> 30 points = parse_input(data_str)
#      31 draw_matrix(points, width=320, height=320)
#
# NameError: name 'data_str' is not defined

# %%
def is_five_apart(init, current):
    return (current - init + 1) % 5 == 0

# %%
class GlucoseItem:
    def __init__(self, type: str, glucose: int, dateString, direction : str = None):
        self.type = type
        self.glucose = glucose
        self.dateString = dateString 
        self.direction = direction

class TreatmentItem:
    def __init__(self, type, dateString, amount):
        self.type = type
        self.date = dateString
        self.amount = int(amount)

class ExerciseItem:
    def __init__(self, type, dateString, amount):
        self.type = type
        self.date = dateString
        self.amount = int(amount)
        print(type)
        print(dateString)
        print(int(amount))
        

formmated_treatments_json = []
json_treatments_data = [{
    "_id": "671bc902af5aaaec8882d7d6",
    "duration": 63,
    "eventType": "Exercise",
    "enteredBy": "Guilherme",
    "created_at": "2024-10-25T15:21:00.000Z",
    "utcOffset": -180,
    "carbs": None,
    "insulin": None
}]
  
for item in json_treatments_data:
    time = datetime.datetime.strptime(item.get("created_at"), "%Y-%m-%dT%H:%M:%S.%fZ")
    if item.get("eventType") == "Carbs":
        if not item.get("carbs"):
            continue
        formmated_treatments_json.append(TreatmentItem("Carbs",
                                            time,
                                            int(item.get("carbs"))))
    elif item.get("eventType") == "Bolus":
        if not item.get("insulin"):
            continue
        formmated_treatments_json.append(TreatmentItem("Bolus",
                                            time,
                                            int(item.get("insulin"))))
    elif item.get("eventType") == "Exercise":
        if item.get('utcOffset'):
            time = time + datetime.timedelta(minutes=item.get('utcOffset'))
        if not item.get("duration"):
            continue
        formmated_treatments_json.append(ExerciseItem("Exercise",
                                            time,
                                            int(item.get("duration"))))
# Out:
# Exercise
# 2024-10-25 12:21:00
# 63

# %%
import json
from datetime import datetime, timedelta

# Replace this with the actual JSON data
json_data = [
  {
    "_id": "ag963REcF6lVsrIOlq8WDQTW",
    "direction": "Flat",
    "sysTime": "2024-10-31T21:55:56.511Z",
    "date": 1730411756511,
    "dateString": "2024-10-31T21:55:56.511Z",
    "type": "sgv",
    "filtered": 185882,
    "noise": 1,
    "sgv": 180,
    "device": "miaomiao3_f942",
    "unfiltered": 185882,
    "utcOffset": 0,
    "mills": 1730411756511
  },
  {
    "_id": "5Ud7PNXEAiaM9UYauvGxJStU",
    "direction": "Flat",
    "sysTime": "2024-10-31T21:50:56.774Z",
    "date": 1730411456774,
    "dateString": "2024-10-31T21:50:56.774Z",
    "type": "sgv",
    "filtered": 187294,
    "noise": 1,
    "sgv": 181,
    "device": "miaomiao3_f942",
    "unfiltered": 187294,
    "utcOffset": 0,
    "mills": 1730411456774
  },
  {
    "_id": "R09rO1ovGxoOtsXw0VOfBD2d",
    "direction": "Flat",
    "sysTime": "2024-10-31T21:45:59.250Z",
    "date": 1730411159250,
    "dateString": "2024-10-31T21:45:59.250Z",
    "type": "sgv",
    "filtered": 186588,
    "noise": 1,
    "sgv": 180,
    "device": "miaomiao3_f942",
    "unfiltered": 186588,
    "utcOffset": 0,
    "mills": 1730411159250
  },
  {
    "_id": "KCodjJiRqnmopip3xR6IPnoZ",
    "date": 1730410857333,
    "sgv": 179,
    "sysTime": "2024-10-31T21:40:57.333Z",
    "unfiltered": 185176,
    "noise": 1,
    "dateString": "2024-10-31T21:40:57.333Z",
    "type": "sgv",
    "direction": "Flat",
    "device": "miaomiao3_f942",
    "filtered": 185176,
    "utcOffset": 0,
    "mills": 1730410857333
  },
  {
    "_id": "sLcmZ6U2KDhHFY35GhGMTg6S",
    "sgv": 180,
    "sysTime": "2024-10-31T21:35:56.561Z",
    "type": "sgv",
    "direction": "Flat",
    "filtered": 185647,
    "noise": 1,
    "date": 1730410556561,
    "dateString": "2024-10-31T21:35:56.561Z",
    "device": "miaomiao3_f942",
    "unfiltered": 185647,
    "utcOffset": 0,
    "mills": 1730410556561
  },
  {
    "_id": "Qp4TrOdUGArRtXv5f4DStjVK",
    "unfiltered": 183059,
    "sysTime": "2024-10-31T21:30:56.632Z",
    "sgv": 177,
    "direction": "Flat",
    "filtered": 183059,
    "noise": 1,
    "direction": "FortyFiveUp",
    "utcOffset": 0,
    "mills": 1730408106942
  },
  {
    "_id": "npqayvD84tYWw95HU7fp3kLM",
    "filtered": 115059,
    "sgv": 109,
    "unfiltered": 115059,
    "date": 1730407807052,
    "device": "miaomiao3_f942",
    "noise": 1,
    "sysTime": "2024-10-31T20:50:07.052Z",
    "type": "sgv",
    "dateString": "2024-10-31T20:50:07.052Z",
    "direction": "FortyFiveUp",
    "utcOffset": 0,
    "mills": 1730407807052
  },
  {
    "_id": "z6JE4qDLobSWMAROupdahKZ3",
    "date": 1730407507172,
    "sgv": 101,
    "sysTime": "2024-10-31T20:45:07.172Z",
    "direction": "FortyFiveUp",
    "dateString": "2024-10-31T20:45:07.172Z",
    "type": "sgv",
    "filtered": 107059,
    "device": "miaomiao3_f942",
    "noise": 1,
    "unfiltered": 107059,
    "utcOffset": 0,
    "mills": 1730407507172
  }]

# Convert each date in the JSON to a datetime object
for i in range(len(json_data) - 1):
    date1 = datetime.utcfromtimestamp(json_data[i]['date'] / 1000)
    date2 = datetime.utcfromtimestamp(json_data[i + 1]['date'] / 1000)
    
    # Calculate the time difference
    time_difference = date1 - date2
    print(f"Time difference between entry {i} and entry {i+1}: {time_difference}")
# Out:
# Time difference between entry 0 and entry 1: 0:04:59.737000
# Time difference between entry 1 and entry 2: 0:04:57.524000
# Time difference between entry 2 and entry 3: 0:05:01.917000
# Time difference between entry 3 and entry 4: 0:05:00.772000
# Time difference between entry 4 and entry 5: 0:04:59.929000
# Time difference between entry 5 and entry 6: 0:05:24.586000
# Time difference between entry 6 and entry 7: 0:05:25.389000
# Time difference between entry 7 and entry 8: 0:04:59.922000
# Time difference between entry 8 and entry 9: 0:04:59.907000
# Time difference between entry 9 and entry 10: 0:05:00.049000
# Time difference between entry 10 and entry 11: 0:04:59.899000
# Time difference between entry 11 and entry 12: 0:04:59.938000
# Time difference between entry 12 and entry 13: 0:04:59.890000
# Time difference between entry 13 and entry 14: 0:04:59.880000

# %%
from GlucoseMatrixDisplay import GlucoseMatrixDisplay

matrix = GlucoseMatrixDisplay()
matrix.run_command_in_loop()
# Out:
# 2024-10-27 04:55:46.115000
# 2024-10-27 01:59:17.820559
# 2024-10-27 04:52:36.223000
# 2024-10-27 01:59:17.820559
# 2024-10-26 19:18:22.345000
# 2024-10-27 01:59:17.820559
# 2024-10-26 17:33:33.430000
# 2024-10-27 01:59:17.820559
# 2024-10-26 15:35:36
# 2024-10-27 01:59:17.820559
# 2024-10-25 21:37:57.112000
# 2024-10-27 01:59:17.820559
# 2024-10-25 18:52:55.845000
# 2024-10-27 01:59:17.820559
# 2024-10-25 18:47:50.391000
# 2024-10-27 01:59:17.820559
# 2024-10-25 13:45:43.933000
# 2024-10-27 01:59:17.820559
# 2024-10-25 13:27:04.960000
# 2024-10-27 01:59:17.820559
# 2024-10-25 12:49:15.190000
# 2024-10-27 01:59:17.820559
